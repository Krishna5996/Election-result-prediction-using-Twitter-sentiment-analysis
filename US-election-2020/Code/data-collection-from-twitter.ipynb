# %%
import csv
import tweepy
import pandas as pd

# %%
#Twitter Keys and Access Tokens

api_key = "Ruq3ombVVxqBrlZpO25EWXln6"

api_key_secret = "OZvoioUlBQ5hJbabDQBqKBlS2bSND4P9DJalFYwQMgmeCMsTGE"

access_token = "722321034-U90pjwxi3QGNBMKD22Dr1oaVNSvdLkSxft1gWKPS"

access_token_secret = "Fvfr3lNJMsrAzDcV8lF3Nd7Xm9FakyTRoQLWI54oQ0rFA"

# %%
#Authenticating the twitter API

auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
#Testing the API connection 

#user = api.me()
#user.name

# %%
candidate_name = ['realDonaldTrump','JoeBiden']

replies_trump = []
replies_biden = []


for candidate in candidate_name:
    for tweet in tweepy.Cursor(api.search_tweets,q='to:'+candidate, result_type='recent',timeout=999999).items(10000):
        if candidate == "realDonaldTrump":
            replies_trump.append(tweet)
            
        elif candidate == "JoeBiden":
            replies_biden.append(tweet)
# Out:
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Unexpected parameter: timeout
# Rate limit reached. Sleeping for: 809
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     174             conn = connection.create_connection(
# --> 175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# c:\users\asus\appdata\local\programs\python\python36\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     186             raise NewConnectionError(
# --> 187                 self, "Failed to establish a new connection: %s" % e
#     188             )
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000217AC639E80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     449                     retries=self.max_retries,
# --> 450                     timeout=timeout
#     451                 )
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785             retries = retries.increment(
# --> 786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787             )
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=to%3AJoeBiden&max_id=1498944069912956929&result_type=recent&timeout=999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000217AC639E80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=to%3AJoeBiden&max_id=1498944069912956929&result_type=recent&timeout=999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000217AC639E80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
#
# During handling of the above exception, another exception occurred:
#
# TweepyException                           Traceback (most recent call last)
# <ipython-input-5-8a7be75d6dd4> in <module>
#       6
#       7 for candidate in candidate_name:
# ----> 8     for tweet in tweepy.Cursor(api.search_tweets,q='to:'+candidate, result_type='recent',timeout=999999).items(10000):
#       9         if candidate == "realDonaldTrump":
#      10             replies_trump.append(tweet)
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\cursor.py in next(self)
#     165
#     166         if self.index >= len(self.results) - 1:
# --> 167             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     168
#     169             model = ModelParser().parse(
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      31         @functools.wraps(method)
#      32         def wrapper(*args, **kwargs):
# ---> 33             return method(*args, **kwargs)
#      34         wrapper.pagination_mode = mode
#      35         return wrapper
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in search_tweets(self, q, **kwargs)
#    1270                 'q', 'geocode', 'lang', 'locale', 'result_type', 'count',
#    1271                 'until', 'since_id', 'max_id', 'include_entities'
# -> 1272             ), q=q, **kwargs
#    1273         )
#    1274
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     220                     )
#     221                 except Exception as e:
# --> 222                     raise TweepyException(f'Failed to send request: {e}').with_traceback(sys.exc_info()[2])
#     223
#     224                 if 200 <= resp.status_code < 300:
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\tweepy\api.py in request(self, method, endpoint, endpoint_parameters, params, headers, json_payload, parser, payload_list, payload_type, post_data, files, require_auth, return_cursors, upload_api, use_cache, **kwargs)
#     217                         method, url, params=params, headers=headers,
#     218                         data=post_data, files=files, json=json_payload,
# --> 219                         timeout=self.timeout, auth=auth, proxies=self.proxy
#     220                     )
#     221                 except Exception as e:
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# c:\users\asus\appdata\local\programs\python\python36\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     517                 raise SSLError(e, request=request)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#     521         except ClosedPoolError as e:
#
# TweepyException: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=to%3AJoeBiden&max_id=1498944069912956929&result_type=recent&timeout=999999 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000217AC639E80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))

# %%
#converting the files into dataframe and to csv

biden_df = pd.DataFrame()
trump_df = pd.DataFrame()

df_names = ['biden_df','trump_df']

for tweet in replies_trump:
    row = {'user': tweet.user.screen_name, 'text': tweet.text.replace('\n', ' ')}
    trump_df = trump_df.append(row, ignore_index=True)
    trump_df.to_csv(r'other/trump_data.csv')
    
for tweet in replies_biden:
    row = {'user': tweet.user.screen_name, 'text': tweet.text.replace('\n', ' ')}
    biden_df = biden_df.append(row, ignore_index=True)
    biden_df.to_csv(r'other/biden_data.csv')

# %%
#replies_trump

# %%
#printing out the shape and the dataset 

print(trump_df.shape)
trump_df.head()
# Out:
# (2046, 2)
#                                                 text           user
# 0  RT @mishakatia46ya1: @realDonaldTrump This man...   chris0416541
# 1  @realdonaldtrump D88FD40B :参戦ID 参加者募集！ Lv120 ホ...    tiga1023325
# 2  @realDonaldTrump @POTUS Will the world come fo...  youtryandfail
# 3  @realDonaldTrump 8C0BEFDF :参戦ID 参加者募集！ Lv150 プ...        d78963d
# 4  @realdonaldtrump 3C448F1D :参戦ID 参加者募集！ Lv120 ホ...    tiga1023325

# %%
print(biden_df.shape)
biden_df.head()
# Out:
# (588, 2)
#                                                 text           user
# 0  RT @elonmusk: @JoeBiden Tesla has created over...    Royaltxgirl
# 1     @JoeBiden 大家不要听美国的谎言，俄罗斯打乌克兰是为了发展中国家，不是为了俄罗斯自己  zengxianwei11
# 2  RT @elonmusk: @JoeBiden Tesla has created over...     youhannaxd
# 3  RT @elonmusk: @JoeBiden Tesla has created over...  Babs_Bunny420
# 4  @JoeBiden : «Putin potrà circondare la capital...  StefanoFeltri
